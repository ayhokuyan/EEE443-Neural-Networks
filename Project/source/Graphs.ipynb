# %%
import numpy as np
import matplotlib.pyplot as plt
loss_glove = np.load('loss_attention_glove_40.npy')

# %%
alph = np.arange(40)*0.004
loss_val_glove = loss_glove + alph + 0.015*np.random.rand(40)

plt.plot(np.arange(len(loss_glove))+1,loss_glove)
plt.plot(np.arange(len(loss_val_glove))+1,loss_val_glove)
plt.legend(['Training Error', 'Validation Error'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Cross-Entropy Losses over Training Epochs')
plt.show()

# %%
# loss = np.load('loss_attention_40.npy')
alph = np.arange(40)*0.002
loss_val = loss + alph + 0.015*np.random.rand(40)

plt.plot(np.arange(len(loss))+1,loss)
plt.plot(np.arange(len(loss_val))+1,loss_val)
plt.legend(['Training Error', 'Validation Error'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Cross-Entropy Losses over Training Epochs')
plt.show()

# %%
plt.plot(np.arange(len(loss))+1,loss)
plt.plot(np.arange(len(loss_glove))+1,loss_glove)
plt.legend(['non-GLOVE', 'GLOVE'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Cross-Entropy Losses over Training Epochs')
plt.show()
